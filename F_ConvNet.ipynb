# %%
# !conda install pybind11
# !conda install opencv
# !conda install yaml

# %%
# !nvidia-smi
# Out:
# Sat Jul  4 13:20:25 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.100      Driver Version: 440.100      CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:01:00.0 Off |                    0 |
# | N/A   33C    P0    73W / 300W |  26314MiB / 32510MiB |    100%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  Off  | 00000000:02:00.0 Off |                    0 |
# | N/A   31C    P0    53W / 300W |  11361MiB / 32510MiB |     15%      Default |
# ...

# %%
import os
os.chdir('/home/kasatkin/Desktop/F-ConvNet/data/kitti/')
# !wget 'https://s3.eu-central-1.amazonaws.com/avg-kitti/data_tracking_image_2.zip'
# !wget 'https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip'
# !wget 'https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip'
# !wget 'https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip'
# !wget 'https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip'
os.chdir('/home/kasatkin/Desktop/F-ConvNet')

os.environ["CUDA_VISIBLE_DEVICES"]="3"
# !export CUDA_VISIBLE_DEVICES=3

# %%
# import os
# os.chdir('/home/kasatkin/Desktop/F-ConvNet/ops')
# # !git clone https://github.com/zhixinwang/frustum-convnet.git
# !bash clean.sh
# !bash make.sh
# os.chdir('../')
# print(os.getcwd())

# %% [markdown]
# # Обучение

# %%
# %%time
# !python kitti/prepare_data.py --gen_train --gen_val --gen_val_rgb_detection --save_dir kitti/data/pickle_data --car_only
# Out:
# -------------  0
# -------------  3
# -------------  7
# -------------  9
# -------------  10
# -------------  11
# -------------  12
# -------------  13
# -------------  14
# -------------  16
# -------------  17
# -------------  18
# -------------  22
# -------------  26
# -------------  29
# -------------  30
# -------------  32
# -------------  34
# -------------  36
# -------------  38
# -------------  41
# -------------  43
# -------------  44
# -------------  45
# -------------  46
# -------------  49
# -------------  51
# -------------  54
# -------------  55
# -------------  56
# -------------  57
# -------------  60
# -------------  64
# -------------  67
# -------------  68
# -------------  69
# -------------  70
# -------------  71
# -------------  72
# -------------  73
# -------------  74
# -------------  75
# -------------  79
# -------------  80
# -------------  82
# -------------  83
# -------------  84
# -------------  85
# -------------  86
# -------------  87
# ...

# %%
# !python train/train_net_det.py --cfg cfgs/det_pedcyc.yaml OUTPUT_DIR output/pedcyc/
# Out:
# /home/kasatkin/Desktop/F-ConvNet/configs/config.py:225: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(cfg_to_load)
# Namespace(cfg_file='cfgs/det_true.yaml', opts=['OUTPUT_DIR', 'output/carpedcyc_true/'])
# config:
#  {'DATA': {'CAR_ONLY': False,
#           'DATASET_NAME': 'KITTI',
#           'DATA_ROOT': 'kitti/data/pickle_data',
#           'EXTEND_FROM_DET': False,
#           'FILE': 'datasets/provider_sample.py',
#           'HEIGHT_HALF': (0.25, 0.5, 1.0, 2.0),
#           'MAX_DEPTH': 70,
#           'NUM_HEADING_BIN': 12,
#           'NUM_SAMPLES': 1024,
#           'NUM_SAMPLES_DET': 512,
#           'PEOPLE_ONLY': False,
#           'RTC': True,
#           'STRIDE': (0.25, 0.5, 1.0, 2.0),
#           'WITH_EXTRA_FEAT': False},
#  'EVAL_MODE': False,
#  'FROM_RGB_DET': True,
#  'IOU_THRESH': 0.7,
#  'LOSS': {'BOX_LOSS_WEIGHT': 1.0,
# ...

# %%
# %%time
# !python train/test_net_det.py --cfg cfgs/det_pedcyc.yaml OUTPUT_DIR output/pedcyc_train TEST.WEIGHTS output/pedcyc_train/model_0050.pth
# Out:
# /home/kasatkin/Desktop/F-ConvNet/configs/config.py:225: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(cfg_to_load)
# config:
#  {'DATA': {'CAR_ONLY': False,
#           'DATASET_NAME': 'KITTI',
#           'DATA_ROOT': 'kitti/data/pickle_data',
#           'EXTEND_FROM_DET': False,
#           'FILE': 'datasets/provider_sample.py',
#           'HEIGHT_HALF': (0.1, 0.2, 0.4, 0.8),
#           'MAX_DEPTH': 70,
#           'NUM_HEADING_BIN': 12,
#           'NUM_SAMPLES': 1024,
#           'NUM_SAMPLES_DET': 512,
#           'PEOPLE_ONLY': True,
#           'RTC': True,
#           'STRIDE': (0.1, 0.2, 0.4, 0.8),
#           'WITH_EXTRA_FEAT': False},
#  'EVAL_MODE': False,
#  'FROM_RGB_DET': True,
#  'IOU_THRESH': 0.5,
#  'LOSS': {'BOX_LOSS_WEIGHT': 1.0,
#           'CORNER_LOSS_WEIGHT': 10.0,
#           'HEAD_REG_WEIGHT': 20.0,
# ...

# %%
# %%time
# !python kitti/prepare_data_refine.py --gen_train --gen_val --gen_val_rgb_detection \
    --save_dir kitti/data/pickle_data_refine --people_only
# Out:
# -------------  0
# -------------  3
# -------------  7
# -------------  9
# -------------  10
# -------------  11
# -------------  12
# -------------  13
# -------------  14
# -------------  16
# -------------  17
# -------------  18
# -------------  22
# -------------  26
# -------------  29
# -------------  30
# -------------  32
# -------------  34
# -------------  36
# -------------  38
# -------------  41
# -------------  43
# -------------  44
# -------------  45
# -------------  46
# -------------  49
# -------------  51
# -------------  54
# -------------  55
# -------------  56
# -------------  57
# -------------  60
# -------------  64
# -------------  67
# -------------  68
# -------------  69
# -------------  70
# -------------  71
# -------------  72
# -------------  73
# -------------  74
# -------------  75
# -------------  79
# -------------  80
# -------------  82
# -------------  83
# -------------  84
# -------------  85
# -------------  86
# -------------  87
# ...

# %%
# !python train/train_net_det.py --cfg cfgs/refine_pedcyc.yaml OUTPUT_DIR output/people_refine/
# !python train/train_net_det.py --cfg cfgs/refine_car.yaml OUTPUT_DIR output/car_refine/

# %%
# %%time
# !python train/test_net_det.py --cfg cfgs/refine_car.yaml \
    OUTPUT_DIR output/car_refine \
    TEST.WEIGHTS output/car_refine/model_0050.pth
# Out:
# /home/kasatkin/Desktop/F-ConvNet/configs/config.py:225: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(cfg_to_load)
# config:
#  {'DATA': {'CAR_ONLY': True,
#           'DATASET_NAME': 'KITTI',
#           'DATA_ROOT': 'kitti/data/pickle_data_refine',
#           'EXTEND_FROM_DET': False,
#           'FILE': 'datasets/provider_sample_refine.py',
#           'HEIGHT_HALF': (0.1, 0.2, 0.4, 0.8),
#           'MAX_DEPTH': 70,
#           'NUM_HEADING_BIN': 12,
#           'NUM_SAMPLES': 512,
#           'NUM_SAMPLES_DET': 512,
#           'PEOPLE_ONLY': False,
#           'RTC': True,
#           'STRIDE': (0.1, 0.2, 0.4, 0.8),
#           'WITH_EXTRA_FEAT': False},
#  'EVAL_MODE': False,
#  'FROM_RGB_DET': True,
#  'IOU_THRESH': 0.7,
#  'LOSS': {'BOX_LOSS_WEIGHT': 1.0,
#           'CORNER_LOSS_WEIGHT': 10.0,
#           'HEAD_REG_WEIGHT': 20.0,
# ...

# %%
# %%time
# !python train/test_net_det.py --cfg cfgs/refine_pedcyc.yaml \
    OUTPUT_DIR output/people_refine \
    TEST.WEIGHTS output/people_refine/model_0050.pth
# Out:
# /home/kasatkin/Desktop/F-ConvNet/configs/config.py:225: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(cfg_to_load)
# config:
#  {'DATA': {'CAR_ONLY': False,
#           'DATASET_NAME': 'KITTI',
#           'DATA_ROOT': 'kitti/data/pickle_data_refine',
#           'EXTEND_FROM_DET': False,
#           'FILE': 'datasets/provider_sample_refine.py',
#           'HEIGHT_HALF': (0.05, 0.1, 0.2, 0.4),
#           'MAX_DEPTH': 70,
#           'NUM_HEADING_BIN': 12,
#           'NUM_SAMPLES': 512,
#           'NUM_SAMPLES_DET': 512,
#           'PEOPLE_ONLY': True,
#           'RTC': True,
#           'STRIDE': (0.05, 0.1, 0.2, 0.4),
#           'WITH_EXTRA_FEAT': False},
#  'EVAL_MODE': False,
#  'FROM_RGB_DET': True,
#  'IOU_THRESH': 0.5,
#  'LOSS': {'BOX_LOSS_WEIGHT': 1.0,
#           'CORNER_LOSS_WEIGHT': 10.0,
#           'HEAD_REG_WEIGHT': 20.0,
# ...

# %% [markdown]
# # Pseudo-Lidar

# %%
# !python kitti/prepare_data.py --gen_val_rgb_detection --save_dir kitti/data/pickle_data_pseudo
# Out:
# det idx: 0/29789, data idx: 1
# det idx: 1/29789, data idx: 1
# det idx: 2/29789, data idx: 1
# det idx: 3/29789, data idx: 2
# det idx: 4/29789, data idx: 4
# det idx: 5/29789, data idx: 4
# det idx: 6/29789, data idx: 4
# det idx: 7/29789, data idx: 4
# det idx: 8/29789, data idx: 4
# det idx: 9/29789, data idx: 4
# det idx: 10/29789, data idx: 4
# det idx: 11/29789, data idx: 5
# det idx: 12/29789, data idx: 6
# det idx: 13/29789, data idx: 6
# det idx: 14/29789, data idx: 6
# det idx: 15/29789, data idx: 6
# det idx: 16/29789, data idx: 6
# det idx: 17/29789, data idx: 6
# det idx: 18/29789, data idx: 8
# det idx: 19/29789, data idx: 8
# det idx: 20/29789, data idx: 8
# det idx: 21/29789, data idx: 8
# det idx: 22/29789, data idx: 8
# det idx: 23/29789, data idx: 8
# det idx: 24/29789, data idx: 8
# det idx: 25/29789, data idx: 8
# det idx: 26/29789, data idx: 8
# det idx: 27/29789, data idx: 8
# det idx: 28/29789, data idx: 8
# det idx: 29/29789, data idx: 15
# ...

# %%
# !python train/test_net_det.py --cfg cfgs/det_pseudo.yaml OUTPUT_DIR output/pseudo_lidar/ TEST.WEIGHTS output/car_train/model_0050.pth
# Out:
# /home/kasatkin/Desktop/F-ConvNet/configs/config.py:225: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(cfg_to_load)
# config:
#  {'DATA': {'CAR_ONLY': False,
#           'DATASET_NAME': 'KITTI',
#           'DATA_ROOT': 'kitti/data/pickle_data_pseudo',
#           'EXTEND_FROM_DET': False,
#           'FILE': 'datasets/provider_sample.py',
#           'HEIGHT_HALF': (0.25, 0.5, 1.0, 2.0),
#           'MAX_DEPTH': 70,
#           'NUM_HEADING_BIN': 12,
#           'NUM_SAMPLES': 1024,
#           'NUM_SAMPLES_DET': 512,
#           'PEOPLE_ONLY': False,
#           'RTC': True,
#           'STRIDE': (0.25, 0.5, 1.0, 2.0),
#           'WITH_EXTRA_FEAT': False},
#  'EVAL_MODE': False,
#  'FROM_RGB_DET': True,
#  'IOU_THRESH': 0.7,
#  'LOSS': {'BOX_LOSS_WEIGHT': 1.0,
#           'CORNER_LOSS_WEIGHT': 10.0,
#           'HEAD_REG_WEIGHT': 20.0,
# ...

# %%
# !python kitti/prepare_data_refine.py --gen_from_folder output/pseudo_lidar/val_nms/result/data --save_dir kitti/data/pickle_data_pseudo_refine
# Out:
# -------------  1
# -------------  2
# -------------  4
# -------------  5
# -------------  6
# -------------  8
# -------------  15
# -------------  19
# -------------  20
# -------------  21
# -------------  23
# -------------  24
# -------------  25
# -------------  27
# -------------  28
# -------------  31
# -------------  33
# -------------  35
# -------------  37
# -------------  39
# -------------  40
# -------------  42
# -------------  47
# -------------  48
# -------------  50
# -------------  52
# -------------  53
# -------------  58
# -------------  59
# -------------  61
# -------------  62
# -------------  63
# -------------  65
# -------------  66
# -------------  76
# -------------  77
# -------------  78
# -------------  81
# -------------  89
# -------------  90
# -------------  93
# -------------  94
# -------------  98
# -------------  102
# -------------  104
# -------------  106
# -------------  107
# -------------  108
# -------------  116
# ...

# %%
# !OUTDIR='output/pseudo_lidar_refine'
# !python train/test_net_det.py --cfg cfgs/refine_pseudo.yaml OUTPUT_DIR output/pseudo_lidar/refine/ \
                                                            TEST.WEIGHTS output/car_train_refine/model_0050.pth \
            OVER_WRITE_TEST_FILE output/pseudo_lidar/val_nms/result/frustum_carpedcyc_val_rgb_detection_refine.pickle
# Out:
# /home/kasatkin/Desktop/F-ConvNet/configs/config.py:225: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(cfg_to_load)
# config:
#  {'DATA': {'CAR_ONLY': False,
#           'DATASET_NAME': 'KITTI',
#           'DATA_ROOT': 'kitti/data/pickle_data_pseudo_refine',
#           'EXTEND_FROM_DET': False,
#           'FILE': 'datasets/provider_sample_refine.py',
#           'HEIGHT_HALF': (0.1, 0.2, 0.4, 0.8),
#           'MAX_DEPTH': 70,
#           'NUM_HEADING_BIN': 12,
#           'NUM_SAMPLES': 512,
#           'NUM_SAMPLES_DET': 512,
#           'PEOPLE_ONLY': False,
#           'RTC': True,
#           'STRIDE': (0.1, 0.2, 0.4, 0.8),
#           'WITH_EXTRA_FEAT': False},
#  'EVAL_MODE': False,
#  'FROM_RGB_DET': True,
#  'IOU_THRESH': 0.7,
#  'LOSS': {'BOX_LOSS_WEIGHT': 1.0,
#           'CORNER_LOSS_WEIGHT': 10.0,
#           'HEAD_REG_WEIGHT': 20.0,
# ...

# %% [markdown]
# # Visualization

# %%
# !python visualization/kitti_object_vis/kitti_object.py \
        --dir /home/kasatkin/Desktop/Pseudo_Lidar_V2/data/kitti/ \
        --lidar /home/kasatkin/Desktop/Pseudo_Lidar_V2/data/kitti/testing/velodyne/ \
        --depthdir /home/kasatkin/Desktop/Pseudo_Lidar_V2/results/sdn_kitti_train_set/gt_depth_maps_test/ \
        --show_lidar_with_depth --img_fov --const_box --vis --split 'testing'
# Out:
# /home/kasatkin/Desktop/Pseudo_Lidar_V2/data/kitti/ testing
# no pred file
# /home/kasatkin/Desktop/Pseudo_Lidar_V2/data/kitti/testing/velodyne/000000.bin
# 0 image shape:  (375, 1242, 3)
# 0 velo  shape:  (125635, 4)
# ======== Objects in Ground Truth ========
# ('All point num: ', 125635)
# ('FOV point num: ', (20537, 4))
# pc_velo (20537, 4)
# ==================== (20537, 4)
# QXcbConnection: XCB error: 145 (Unknown), sequence: 171, resource id: 0, major code: 139 (Unknown), minor code: 20
# ^C
# Traceback (most recent call last):
#   File "visualization/kitti_object_vis/kitti_object.py", line 945, in <module>
#     dataset_viz(args.dir, args)
#   File "visualization/kitti_object_vis/kitti_object.py", line 797, in dataset_viz
#     input_str = raw_input()
# KeyboardInterrupt

# %%
# !python visualization/kitti_object_vis/kitti_object.py \
        --dir /home/kasatkin/Desktop/Pseudo_Lidar_V2/data/kitti/ \
        --lidar /home/kasatkin/Desktop/Pseudo_Lidar_V2/results/sdn_kitti_train_set/pseudo_lidar_test_corrected/ \
        --depthdir /home/kasatkin/Desktop/Pseudo_Lidar_V2/results/sdn_kitti_train_set/depth_maps_test_corrected/ \
        --show_lidar_with_depth --img_fov --const_box --vis --split 'testing'
# Out:
# /home/kasatkin/Desktop/Pseudo_Lidar_V2/data/kitti/ testing
# no pred file
# /home/kasatkin/Desktop/Pseudo_Lidar_V2/results/sdn_kitti_train_set/pseudo_lidar_test_corrected/000000.bin
# 0 image shape:  (375, 1242, 3)
# 0 velo  shape:  (462806, 4)
# ======== Objects in Ground Truth ========
# ('All point num: ', 462806)
# ('FOV point num: ', (61175, 4))
# pc_velo (61175, 4)
# ==================== (61175, 4)
# QXcbConnection: XCB error: 145 (Unknown), sequence: 171, resource id: 0, major code: 139 (Unknown), minor code: 20
# ^C
# Traceback (most recent call last):
#   File "visualization/kitti_object_vis/kitti_object.py", line 945, in <module>
#     dataset_viz(args.dir, args)
#   File "visualization/kitti_object_vis/kitti_object.py", line 797, in dataset_viz
#     input_str = raw_input()
# KeyboardInterrupt

# %%
# !python visualization/kitti_object_vis/viz_lidar.py \
        --dir /home/kasatkin/Desktop/Pseudo_Lidar_V2/data/kitti/ \
        --lidar /home/kasatkin/Desktop/Pseudo_Lidar_V2/results/sdn_kitti_train_set/pseudo_lidar_test_corrected/ \
        --depthdir /home/kasatkin/Desktop/Pseudo_Lidar_V2/results/sdn_kitti_train_set/depth_maps_test_corrected/ \
        --save_lidar_with_depth --img_fov --const_box --split 'testing' \
        --outdir /home/kasatkin/Desktop/F-ConvNet/output/viz_Pseudo_Lidar/images/
# Out:
# /home/kasatkin/Desktop/Pseudo_Lidar_V2/data/kitti/ testing
# no pred file
# /home/kasatkin/Desktop/Pseudo_Lidar_V2/results/sdn_kitti_train_set/pseudo_lidar_test_corrected/000000.bin
# 0 image shape:  (375, 1242, 3)
# 0 velo  shape:  (462806, 4)
# ======== Objects in Ground Truth ========
# ('All point num: ', 462806)
# ('FOV point num: ', (61175, 4))
# pc_velo (61175, 4)
# ==================== (61175, 4)
# QXcbConnection: XCB error: 145 (Unknown), sequence: 171, resource id: 0, major code: 139 (Unknown), minor code: 20
# ^C
# Traceback (most recent call last):
#   File "visualization/kitti_object_vis/viz_lidar.py", line 445, in <module>
#     save_images(args.dir, args.outdir, args)
#   File "visualization/kitti_object_vis/viz_lidar.py", line 337, in save_images
#     input_str = raw_input()
# KeyboardInterrupt
